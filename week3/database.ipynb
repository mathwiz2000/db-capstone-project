# %%
import mysql.connector as connector

# %%
connection = connector.connect(user = "root", password = "Root2root!")

# %%
cursor=connection.cursor()
cursor.execute("use mydb")
print(cursor.fetchall())
# Out:
# []

# %%
show_tables_query = "SHOW tables" 
cursor.execute(show_tables_query)
print(cursor.fetchall())
# Out:
# [('Bookings',), ('Customers',), ('Employees',), ('Menu',), ('MenuItem',), ('OrderDelivery',), ('Orders',), ('OrdersView',)]

# %%
query = """
SELECT c.CustomerID,c.Name,Cost,c.City,c.Country,c.PostalCode 
from Orders o inner join Customers c on o.CustomerID=c.CustomerID
where Cost>60;
"""
cursor.execute(query)
results = cursor.fetchall()
print(results)
# Out:
# [(1, 'Laney Fadden', Decimal('125'), 'Daruoyan', 'China', '993-0031'), (2, 'Giacopo Bramich', Decimal('235'), 'Ongjin', 'North Korea', '216282'), (3, 'Lia Bonar', Decimal('75'), 'Quince Mil', 'Peru', '663246'), (4, 'Merrill Baudon', Decimal('220'), 'Susaki', 'Japan', '987-0352'), (5, 'Tasia Fautly', Decimal('320'), 'Tobruk', 'Libya', '351 01'), (6, 'Angel Veschambre', Decimal('210'), 'Rafael Hernandez Ochoa', 'Mexico', '93995'), (7, 'Sheilah Maestro', Decimal('310'), 'Belozrskoye', 'Russia', '641360'), (8, 'Audie Willcocks', Decimal('225'), 'Pvoa do Valado', 'Portugal', '3810-760'), (9, 'Mart Malsher', Decimal('190'), 'Galbshtadt', 'Russia', '692769'), (10, 'Magdalen Lacheze', Decimal('98'), 'Fuyang', 'China', '649-6326'), (11, 'Margarita Mancktelow', Decimal('168'), 'Pindiga', 'Nigeria', '33619'), (12, 'Ashil Brogini', Decimal('102'), 'Wakayamashi', 'Japan', '649-6326'), (13, 'Arthur Mathewson', Decimal('93'), 'Qingshan', 'China', '353715'), (15, 'Tiffani Halstead', Decimal('92'), 'Chelbasskaya', 'Russia', '353715'), (16, 'Roddie Winterbotham', Decimal('133'), 'Leticia', 'Colombia', '910008'), (18, 'Tony Crabtree', Decimal('84'), 'Kuzhu', 'China', '993-0032'), (19, 'Tamarah Filasov', Decimal('69'), 'Kertamukti', 'Indonesia', '1110210'), (20, 'Pen Pruce', Decimal('120'), 'Yeghegnut', 'Armenia', '1557174'), (21, 'Boot Burree', Decimal('125'), 'Baisangguan', 'China', '987-0353'), (22, 'Sabra Calbreath', Decimal('235'), 'Frantikovy Lzn', 'Czech Republic', '352 01'), (23, 'Obidiah Zanicchi', Decimal('75'), 'Tabu', 'Indonesia', '1188725'), (24, 'Anders Stowe', Decimal('220'), 'Daanshan', 'China', '1736090'), (25, 'Locke Janaway', Decimal('320'), 'Jelat', 'Indonesia', '3810-761'), (26, 'Kaylyn Colebourne', Decimal('210'), 'Shuangqiao', 'China', '692770'), (27, 'Noni Quickenden', Decimal('310'), 'MontRoyal', 'Canada', '649-6327'), (28, 'Alan Paskell', Decimal('225'), 'Longzui', 'China', '33620'), (29, 'Anny Pattemore', Decimal('190'), 'Karanganyar', 'Indonesia', '649-6327'), (30, 'Les Harmson', Decimal('98'), 'Podkamennaya Tunguska', 'Russia', '353716'), (31, 'Horatio Lundy', Decimal('168'), 'Huangcun', 'China', '352 01'), (32, 'Sibley Rodder', Decimal('102'), 'Tyvriv', 'Ukraine', '112351.333333333'), (33, 'Dniren Copperwaite', Decimal('93'), 'Zhuhu', 'China', '-47696.6666666667'), (35, 'Alison Jamieson', Decimal('92'), 'Cambu', 'Brazil', '993-0033'), (36, 'Dre Danher', Decimal('133'), 'Libei', 'China', '2004138'), (38, 'Adiana Shirtliff', Decimal('84'), 'Haradzyeya', 'Belarus', '987-0354'), (39, 'Derry Davis', Decimal('69'), 'La Loma', 'Panama', '353 01'), (40, 'Lenci McFadzean', Decimal('120'), 'El Triunfo de la Cruz', 'Honduras', '2283455'), (41, 'Uriel Grooby', Decimal('125'), 'Izumi', 'Japan', '2830820'), (42, 'Jillayne Gaiford', Decimal('235'), 'Blaevo', 'Kazakhstan', '3810-762'), (43, 'Tiertza Doogan', Decimal('75'), 'Ovsyanka', 'Russia', '692771'), (44, 'Ilario Michie', Decimal('220'), 'Pindiga', 'Nigeria', '649-6328'), (45, 'Sarah Plaschke', Decimal('320'), 'Narathiwat', 'Thailand', '33621'), (46, 'Skipp Lowater', Decimal('210'), 'Pacaraos', 'Peru', '649-6328'), (47, 'Maddalena Wolfinger', Decimal('310'), 'Senanga', 'Zambia', '353717'), (48, 'Mariquilla Labbe', Decimal('225'), 'Nots', 'Togo', '353 01'), (49, 'Cornelius Harkess', Decimal('190'), 'Morelos', 'Mexico', '-367792.666666667'), (50, 'Erv Padrick', Decimal('98'), 'Phichai', 'Thailand', '-527840.666666667'), (51, 'Fielding Struys', Decimal('168'), 'Shensuo', 'China', '-687888.666666667'), (52, 'Purcell Eyer', Decimal('125'), 'Qulsary', 'Kazakhstan', '993-0034'), (53, 'Pietra Dibdall', Decimal('144'), 'El Alamo', 'Mexico', '2898066'), (54, 'Dyanne Labbet', Decimal('102'), 'Samanggen', 'Indonesia', '3345030'), (55, 'Elsworth Stannas', Decimal('93'), 'Jinhai', 'China', '987-0355'), (57, 'Calvin Aucock', Decimal('92'), 'Ngarus', 'Indonesia', '3378185'), (58, 'Prudence Eastlake', Decimal('133'), 'Stockholm', 'Sweden', '3925550'), (60, 'Jerrie Jiran', Decimal('84'), 'Lorena ...
